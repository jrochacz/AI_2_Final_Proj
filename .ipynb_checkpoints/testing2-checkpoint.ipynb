# %%
#Import modules 
import torch
import torchvision
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
import torchvision.datasets as datsets
from torchvision.transforms import ToTensor
from torch.utils.data.sampler import SubsetRandomSampler
from torchvision.utils import make_grid
from torch.utils.data.dataloader import DataLoader
from torch.utils.data import random_split
# %matplotlib inline

# Use a white background for matplotlib figures
matplotlib.rcParams['figure.facecolor'] = '#ffffff'
# Out:
# 1

# %%
#Import dataset 
dataset = datsets.FashionMNIST(root='data/', download=True, transform=ToTensor())

# %%
#Show image of one example 
image, label = dataset[0]
print('image.shape:', image.shape)
plt.imshow(image.permute(1, 2, 0), cmap='gray')
print('Label:', label)
# Out:
# image.shape: torch.Size([1, 28, 28])
# Label: 9

# %%
#Split the train and test indicies 
def split_indices(n,val_pct):
    #determine size of validation set
    n_val = int(n*val_pct)
    #create random permutation of 0 to n-1
    idxs = np.random.permutation(n)
    #Pick first n_val random indices as validation set
    return idxs[n_val:], idxs[:n_val]

# %%
#Make 40% of the data testing data 
train_indices, val_indices = split_indices(len(dataset), 0.4)

print(len(train_indices))
print(len(val_indices))
print("Random Validation Samples:", val_indices[:5])
# Out:
# 36000
# 24000
# Random Validation Samples: [26884 35834 50274 50592 48879]

# %%
#Create the training and testing batches 
batch_size=512

#Training sampler and data loader
train_sampler = SubsetRandomSampler(train_indices)
train_loader = DataLoader(dataset, 
                          batch_size, sampler = train_sampler)

#Validation sampler and data loader
val_sampler = SubsetRandomSampler(val_indices)
val_loader = DataLoader(dataset, 
                        batch_size, sampler = val_sampler)

# %%
#Show the images of each batch 
for images, _ in train_loader:
    print('images.shape:', images.shape)
    plt.figure(figsize=(16,8))
    plt.axis('off')
    plt.imshow(make_grid(images, nrow=16).permute((1, 2, 0)))
    break
# Out:
# images.shape: torch.Size([512, 1, 28, 28])

# %%
#USe cuda when avilable 
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
device
# Out:
# device(type='cuda')

# %%
for images, labels in train_loader:
    print(images.shape)
    images = to_device(images, device)
    print(images.device)
    break
# Out:
# torch.Size([512, 1, 28, 28])
# cuda:0

# %%
#Load the training and testing data 
train_loader = DeviceDataLoader(train_loader, device)
val_loader = DeviceDataLoader(val_loader, device)

# %%
#load the ipynb files 
# %run Model.ipynb
# %run DeviceDataLoader.ipynb
# Out:
# 1

# %%
#Make the model with the respective params and put it into your GPU/CPU device 
model = actModel(in_dim=784, hid_dim=32, out_dim=10, n_layer=5)
to_device(model, device)
# Out:
# actModel(
#   (in_proj): Linear(in_features=784, out_features=32, bias=True)
#   (layers): ModuleList(
#     (0-4): 5 x ResidualBlock(
#       (proj): Linear(in_features=32, out_features=32, bias=True)
#       (norm): RMSNorm((32,), eps=None, elementwise_affine=True)
#       (activation): squarePlus1()
#     )
#   )
#   (norm): RMSNorm((32,), eps=None, elementwise_affine=True)
#   (out_proj): Linear(in_features=32, out_features=10, bias=True)
#   (activation): Softmax(dim=1)
#   (criterion): CrossEntropyLoss()
# )

# %%
history = []
LR = [0.5, 0.25, 0.125]

# %%
#Fit the model 
fit(epochs=1, lr=0.001, mo=0, model=model, train_loader=train_loader, val_loader=val_loader)
# Out:
# Epoch [0] val_loss: 2.2985, val_acc: 0.1150, time: 2.7325 s
# [{'val_loss': 2.2984890937805176,
#   'val_acc': 0.11503253132104874,
#   'epoch_time': 2.732516050338745}]

# %%
#Fit the model 
for i in range(len(LR)):
    history += fit(epochs=10, lr=LR[i], mo=0.1, model=model, train_loader=train_loader, val_loader=val_loader)
# Out:
# Epoch [0] val_loss: 1.8306, val_acc: 0.6338, time: 2.5450 s
# Epoch [1] val_loss: 1.7593, val_acc: 0.7059, time: 2.4246 s
# Epoch [2] val_loss: 1.7155, val_acc: 0.7488, time: 2.5039 s
# Epoch [3] val_loss: 1.7066, val_acc: 0.7596, time: 2.5075 s
# Epoch [4] val_loss: 1.7167, val_acc: 0.7491, time: 2.4705 s
# Epoch [5] val_loss: 1.7001, val_acc: 0.7640, time: 2.4962 s
# Epoch [6] val_loss: 1.6860, val_acc: 0.7774, time: 2.5122 s
# Epoch [7] val_loss: 1.7104, val_acc: 0.7513, time: 2.4048 s
# Epoch [8] val_loss: 1.6935, val_acc: 0.7682, time: 2.5322 s
# Epoch [9] val_loss: 1.7109, val_acc: 0.7559, time: 2.5274 s
# Epoch [0] val_loss: 1.6238, val_acc: 0.8423, time: 2.4096 s
# Epoch [1] val_loss: 1.6203, val_acc: 0.8461, time: 2.5130 s
# Epoch [2] val_loss: 1.6330, val_acc: 0.8310, time: 2.4991 s
# Epoch [3] val_loss: 1.6261, val_acc: 0.8390, time: 2.4444 s
# Epoch [4] val_loss: 1.6095, val_acc: 0.8545, time: 2.4956 s
# Epoch [5] val_loss: 1.6460, val_acc: 0.8177, time: 2.4873 s
# Epoch [6] val_loss: 1.6330, val_acc: 0.8312, time: 2.4365 s
# Epoch [7] val_loss: 1.6355, val_acc: 0.8293, time: 2.5250 s
# Epoch [8] val_loss: 1.6126, val_acc: 0.8526, time: 2.4929 s
# Epoch [9] val_loss: 1.6180, val_acc: 0.8457, time: 2.4672 s
# Epoch [0] val_loss: 1.6043, val_acc: 0.8599, time: 2.5124 s
# Epoch [1] val_loss: 1.6041, val_acc: 0.8597, time: 2.5716 s
# Epoch [2] val_loss: 1.6070, val_acc: 0.8575, time: 2.4620 s
# Epoch [3] val_loss: 1.6076, val_acc: 0.8558, time: 2.5386 s
# Epoch [4] val_loss: 1.6015, val_acc: 0.8630, time: 2.4844 s
# Epoch [5] val_loss: 1.6026, val_acc: 0.8615, time: 2.4110 s
# Epoch [6] val_loss: 1.6001, val_acc: 0.8639, time: 2.4469 s
# Epoch [7] val_loss: 1.6040, val_acc: 0.8598, time: 2.4992 s
# Epoch [8] val_loss: 1.6028, val_acc: 0.8608, time: 2.3972 s
# Epoch [9] val_loss: 1.6024, val_acc: 0.8601, time: 2.4227 s

# %%
#Plot the losses 
if 1==0: 
    losses = [x['val_loss'] for x in history]
    plt.plot(np.array(losses), '-x')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Loss vs. No. of epochs');

# %%
accuracies = [x['val_acc'] for x in history]
plt.plot(-np.log(1-np.array(accuracies)), '-x')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.title('Accuracy vs. No. of epochs');
print(max(-np.log(1-np.array(accuracies))))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 accuracies = [x['val_acc'] for x in history]
#       2 plt.plot(-np.log(1-np.array(accuracies)), '-x')
#       3 plt.xlabel('epoch')
#
# NameError: name 'history' is not defined

# %%
time = [x['epoch_time'] for x in history]
plt.plot(time, '-x')
plt.xlabel('epoch')
plt.ylabel('time (s)')
plt.title('Time per epoch');

# %%
np.mean(time), np.std(time)
# Out:
# (np.float64(2.522271728515625), np.float64(0.058678217560709164))

# %%
#Find statistics about the parameter weighst 
a_params = []
b_params = []
c_params = []

for i in range(50):
    a_params += [float(model.layers[i].activation.a)]
    b_params += [float(model.layers[i].activation.b)]
    c_params += [float(model.layers[i].activation.c)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 6
#       3 c_params = []
#       5 for i in range(50):
# ----> 6     a_params += [float(model.layers[i].activation.a)]
#       7     b_params += [float(model.layers[i].activation.b)]
#       8     c_params += [float(model.layers[i].activation.c)]
#
# File ~\anaconda3\envs\ENV\Lib\site-packages\torch\nn\modules\module.py:1729, in Module.__getattr__(self, name)
#    1727     if name in modules:
#    1728         return modules[name]
# -> 1729 raise AttributeError(f"'{type(self).__name__}' object has no attribute '{name}'")
#
# AttributeError: 'squarePlus1' object has no attribute 'a'

# %%
np.mean(a_params), np.std(a_params)

# %%
np.mean(b_params), np.std(b_params)

# %%
np.mean(c_params), np.std(c_params)

# %%
import numpy as np 
import plotly.express as px

# %%
plt.boxplot(a_params)
plt.show()

# %%
plt.boxplot(b_params)
plt.show()

# %%
plt.boxplot(c_params)
plt.show()
